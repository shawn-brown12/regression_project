# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
from math import sqrt
from scipy.stats import pearsonr, spearmanr

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, explained_variance_score

from sklearn.feature_selection import SelectKBest, f_regression, RFE
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, PolynomialFeatures
from sklearn.linear_model import LassoLars, LinearRegression, TweedieRegressor

import acquire
import prepare
import explore
import model

# %matplotlib inline
pd.options.display.max_columns = None

import warnings
warnings.filterwarnings("ignore")

seed = 42

# %%
df = acquire.get_zillow()

# %%
df = prepare.prep_zillow(df)

# %%
df
# Out:
#        bedrooms  bathrooms    sqft  tax_value  year_built    fips
# 0           3.0        2.0  1175.0   327859.0      1953.0  6037.0
# 1           3.0        2.0  1630.0    63948.0      1953.0  6037.0
# 2           2.0        2.0  1206.0   356218.0      1954.0  6037.0
# 3           3.0        2.0  1790.0   242773.0      1964.0  6037.0
# 4           3.0        2.0  1400.0   251246.0      1953.0  6037.0
# ...         ...        ...     ...        ...         ...     ...
# 56075       3.0        2.0  1400.0   318206.0      1951.0  6037.0
# 56076       4.0        2.0  1446.0   140804.0      1951.0  6037.0
# 56077       4.0        2.0  1584.0   412114.0      1955.0  6037.0
# 56078       4.0        2.0  1584.0   186627.0      1955.0  6037.0
# 56079       3.0        1.0  1253.0   377082.0      1951.0  6037.0
#
# [55736 rows x 6 columns]

# %%
cols = ['bedrooms', 'bathrooms', 'sqft', 'tax_value', 'year_built', 'fips']

# %%
df = prepare.remove_outliers(df, 2, cols)

# %%
df
# Out:
#        bedrooms  bathrooms    sqft  tax_value  year_built    fips
# 0           3.0        2.0  1175.0   327859.0      1953.0  6037.0
# 1           3.0        2.0  1630.0    63948.0      1953.0  6037.0
# 2           2.0        2.0  1206.0   356218.0      1954.0  6037.0
# 3           3.0        2.0  1790.0   242773.0      1964.0  6037.0
# 4           3.0        2.0  1400.0   251246.0      1953.0  6037.0
# ...         ...        ...     ...        ...         ...     ...
# 56075       3.0        2.0  1400.0   318206.0      1951.0  6037.0
# 56076       4.0        2.0  1446.0   140804.0      1951.0  6037.0
# 56077       4.0        2.0  1584.0   412114.0      1955.0  6037.0
# 56078       4.0        2.0  1584.0   186627.0      1955.0  6037.0
# 56079       3.0        1.0  1253.0   377082.0      1951.0  6037.0
#
# [46084 rows x 6 columns]

# %%
train, validate, test = prepare.subset_df(df)
# Out:
# (27650, 6) (9217, 6) (9217, 6)

# %%
X_train, y_train, X_validate, y_validate, X_test, y_test = model.xy_subsets(train, validate, test, 'tax_value')

# %%
X_train
# Out:
#        bedrooms  bathrooms    sqft  year_built    fips
# 39518       4.0        3.0  1888.0      1972.0  6059.0
# 36470       4.0        2.0  1779.0      1996.0  6037.0
# 14646       4.0        3.0  2759.0      1990.0  6037.0
# 6714        4.0        2.0  1446.0      1947.0  6037.0
# 44146       3.0        2.0  1667.0      1941.0  6059.0
# ...         ...        ...     ...         ...     ...
# 14332       3.0        2.0  1509.0      1957.0  6037.0
# 54643       5.0        2.0  2268.0      1955.0  6059.0
# 46604       3.0        2.0  1832.0      1952.0  6037.0
# 927         3.0        1.0  1723.0      1950.0  6037.0
# 19156       5.0        2.0  2013.0      1964.0  6059.0
#
# [27650 rows x 5 columns]

# %%
cols = ['sqft', 'year_built']

X_train_scaled, X_validate_scaled, X_test_scaled = prepare.scale_data(X_train, X_validate, X_test, MinMaxScaler(), cols)

# %%
X_train_scaled.shape, X_validate_scaled.shape, X_test_scaled.shape
# Out:
# ((27650, 5), (9217, 5), (9217, 5))

# %%
X_train_scaled
# Out:
#        bedrooms  bathrooms      sqft  year_built    fips
# 39518       4.0        3.0  0.410496    0.603604  6059.0
# 36470       4.0        2.0  0.378717    0.819820  6037.0
# 14646       4.0        3.0  0.664431    0.765766  6037.0
# 6714        4.0        2.0  0.281633    0.378378  6037.0
# 44146       3.0        2.0  0.346064    0.324324  6059.0
# ...         ...        ...       ...         ...     ...
# 14332       3.0        2.0  0.300000    0.468468  6037.0
# 54643       5.0        2.0  0.521283    0.450450  6059.0
# 46604       3.0        2.0  0.394169    0.423423  6037.0
# 927         3.0        1.0  0.362391    0.405405  6037.0
# 19156       5.0        2.0  0.446939    0.531532  6059.0
#
# [27650 rows x 5 columns]

# %%
def rfe(n_features, X_train, y_train):
    
    lm = LinearRegression()
    rfe = RFE(lm, n_features_to_select=n_features)

    rfe.fit(X_train, y_train)

    ranks = rfe.ranking_
    columns = X_train.columns.tolist()
    
    feature_ranks = pd.DataFrame({'ranking': ranks,
                              'feature': columns})

    feature_ranks = feature_ranks.sort_values('ranking')

    return pd.DataFrame(feature_ranks).head(n_features)

# %%
def f_selector(k, X_train, y_train):
    
    f_selector = SelectKBest(f_regression, k=k)

    f_selector.fit(X_train, y_train)

    f_select_mask = f_selector.get_support()

    select_k_best_features = X_train.iloc[:,f_select_mask]
    
    #print(select_k_best_features.head(k))
    
    return pd.DataFrame(select_k_best_features)

# %%
def create_preds_df(y_train):
    
    preds_df = pd.DataFrame({'actual': y_train})

    preds_df['baseline_median'] = y_train.median()
    
    return preds_df

# %%
def lin_regression(X_train, y_train):

    lm = LinearRegression()

    lm.fit(X_train, y_train)
    
    preds_df['lm_preds'] = lm.predict(X_train)
    
    return preds_df

# %%
def lasso_lars(X_train, y_train, alpha=.1):
    
    lasso = LassoLars(alpha=alpha)

    lasso.fit(X_train, y_train)

    preds_df['lasso_preds'] = lasso.predict(X_train)
    
    return preds_df

# %%
def glm_model(X_train, y_train, power=0):
    
    tweedie = TweedieRegressor(power=power)

    tweedie.fit(X_train, y_train)

    preds_df['tweedie_preds'] = tweedie.predict(X_train)
    
    return preds_df

# %%
def poly_subset(X_train, y_train, degree=2):
    
    pf = PolynomialFeatures(degree=degree)

    pf.fit(X_train, y_train)

    X_polynomial = pf.transform(X_train)
    
    return X_polynomial

# %%
def poly_model(X_polynomial, y_train, m):
    
    model = m

    model.fit(X_polynomial, y_train)

    preds_df['poly_preds'] = model.predict(X_polynomial)
    
    return preds_df

# %%
def get_rmses(preds_df):
    
    lm_rmse = sqrt(mean_squared_error(preds_df['lm_preds'], preds_df['actual']))
    lasso_rmse = sqrt(mean_squared_error(preds_df['actual'], preds_df['lasso_preds']))
    tweedie_rmse = sqrt(mean_squared_error(preds_df['actual'], preds_df['tweedie_preds']))
    poly_rmse = sqrt(mean_squared_error(preds_df['actual'], preds_df['poly_preds']))
    
    print(f'Linear Regression RMSE is: {lm_rmse}')
    print(f'Lasso-Lars Regression RMSE is: {lasso_rmse}')
    print(f'GLM Regression RMSE is: {tweedie_rmse}')
    print(f'Polynomial Regression RMSE is: {poly_rmse}')
    
    results = pd.DataFrame({'model':['linear', 'lasso', 'tweedie_norm', 'linear_poly'],
                            'rmse':[lm_rmse, lasso_rmse, tweedie_norm, poly_rmse]})

    return results

# %%
def model_results():

    results = pd.DataFrame({'model':['linear', 'lasso', 'tweedie_norm', 'linear_poly'],
                            'rmse':[lm_rmse, lasso_rmse, tweedie_norm, poly_rmse]})

    return results

# %%
def hist_charts(df):

    for col in df:

        plt.hist(df[col], bins=25)
        plt.title(f'{col} distribution')
        plt.show()

# %%
X_train_scaled = pd.get_dummies(X_train_scaled, columns=['bedrooms', 'bathrooms'])

# %%
X_train_scaled
# Out:
#            sqft  year_built    fips  bedrooms_2.0  bedrooms_3.0  bedrooms_4.0  \
# 39518  0.410496    0.603604  6059.0             0             0             1
# 36470  0.378717    0.819820  6037.0             0             0             1
# 14646  0.664431    0.765766  6037.0             0             0             1
# 6714   0.281633    0.378378  6037.0             0             0             1
# 44146  0.346064    0.324324  6059.0             0             1             0
# ...         ...         ...     ...           ...           ...           ...
# 14332  0.300000    0.468468  6037.0             0             1             0
# 54643  0.521283    0.450450  6059.0             0             0             0
# 46604  0.394169    0.423423  6037.0             0             1             0
# 927    0.362391    0.405405  6037.0             0             1             0
# 19156  0.446939    0.531532  6059.0             0             0             0
#
#        bedrooms_5.0  bathrooms_1.0  bathrooms_1.5  bathrooms_2.0  \
# 39518             0              0              0              0
# 36470             0              0              0              1
# 14646             0              0              0              0
# 6714              0              0              0              1
# 44146             0              0              0              1
# ...             ...            ...            ...            ...
# 14332             0              0              0              1
# 54643             1              0              0              1
# 46604             0              0              0              1
# 927               0              1              0              0
# 19156             1              0              0              1
#
#        bathrooms_2.5  bathrooms_3.0  bathrooms_3.5  bathrooms_4.0  \
# 39518              0              1              0              0
# 36470              0              0              0              0
# 14646              0              1              0              0
# 6714               0              0              0              0
# 44146              0              0              0              0
# ...              ...            ...            ...            ...
# 14332              0              0              0              0
# 54643              0              0              0              0
# 46604              0              0              0              0
# 927                0              0              0              0
# 19156              0              0              0              0
#
#        bathrooms_4.5
# 39518              0
# 36470              0
# 14646              0
# 6714               0
# 44146              0
# ...              ...
# 14332              0
# 54643              0
# 46604              0
# 927                0
# 19156              0
#
# [27650 rows x 15 columns]

# %% [markdown]
# ## linear regression model #1

# %%
preds_df = lin_regression(X_train_scaled, y_train)

# %%
lm_rmse = sqrt(mean_squared_error(preds_df['lm_preds'], preds_df['actual']))

lm_rmse
# Out:
# 201151.25482385387

# %%
preds_df
# Out:
#          actual  baseline_median  lm_preds    lasso_preds  tweedie_preds  \
# 39518  367584.0         305203.5  382336.0  382371.938598  373393.240084
# 36470  414224.0         305203.5  334848.0  335263.900366  325013.299560
# 14646  565097.0         305203.5  529600.0  530739.880620  532005.673971
# 6714   238731.0         305203.5  275200.0  274215.856123  282799.455621
# 44146  256532.0         305203.5  339264.0  338117.607110  330480.117703
# ...         ...              ...       ...            ...            ...
# 14332  176100.0         305203.5  314048.0  313181.452828  310459.997083
# 54643   77121.0         305203.5  374016.0  372960.605076  361461.451270
# 46604  125361.0         305203.5  367744.0  367003.300448  353644.608524
# 927    114100.0         305203.5  327232.0  331086.371150  296333.990329
# 19156  491885.0         305203.5  332032.0  330988.408923  326291.021732
#
#        poly_preds
# 39518    382336.0
# 36470    334848.0
# 14646    529600.0
# 6714     275200.0
# 44146    339264.0
# ...           ...
# 14332    314048.0
# 54643    374016.0
# 46604    367744.0
# 927      327232.0
# 19156    332032.0
#
# [27650 rows x 6 columns]

# %%
sqrt(mean_squared_error(preds_df['actual'], preds_df['baseline_median']))
# Out:
# 236356.89463948304

# %% [markdown]
# ## lasso lars model #1

# %%
preds_df = lasso_lars(X_train_scaled, y_train)

# %%
preds_df
# Out:
#          actual  baseline_median  lm_preds    lasso_preds  tweedie_preds  \
# 39518  367584.0         305203.5  382336.0  382371.938598  373393.240084
# 36470  414224.0         305203.5  334848.0  335263.900366  325013.299560
# 14646  565097.0         305203.5  529600.0  530739.880620  532005.673971
# 6714   238731.0         305203.5  275200.0  274215.856123  282799.455621
# 44146  256532.0         305203.5  339264.0  338117.607110  330480.117703
# ...         ...              ...       ...            ...            ...
# 14332  176100.0         305203.5  314048.0  313181.452828  310459.997083
# 54643   77121.0         305203.5  374016.0  372960.605076  361461.451270
# 46604  125361.0         305203.5  367744.0  367003.300448  353644.608524
# 927    114100.0         305203.5  327232.0  331086.371150  296333.990329
# 19156  491885.0         305203.5  332032.0  330988.408923  326291.021732
#
#        poly_preds
# 39518    382336.0
# 36470    334848.0
# 14646    529600.0
# 6714     275200.0
# 44146    339264.0
# ...           ...
# 14332    314048.0
# 54643    374016.0
# 46604    367744.0
# 927      327232.0
# 19156    332032.0
#
# [27650 rows x 6 columns]

# %%
lasso_rmse = sqrt(mean_squared_error(preds_df['actual'], preds_df['lasso_preds']))
lasso_rmse
# Out:
# 201145.61629488488

# %% [markdown]
# ## glm model #1

# %%
preds_df = preds_df.drop(columns='tweedie_preds')

# %%
glm_model(X_train_scaled, y_train, 2)
# Out:
#          actual  baseline_median  lm_preds    lasso_preds  poly_preds  \
# 39518  367584.0         305203.5  382336.0  382371.938598    382336.0
# 36470  414224.0         305203.5  334848.0  335263.900366    334848.0
# 14646  565097.0         305203.5  529600.0  530739.880620    529600.0
# 6714   238731.0         305203.5  275200.0  274215.856123    275200.0
# 44146  256532.0         305203.5  339264.0  338117.607110    339264.0
# ...         ...              ...       ...            ...         ...
# 14332  176100.0         305203.5  314048.0  313181.452828    314048.0
# 54643   77121.0         305203.5  374016.0  372960.605076    374016.0
# 46604  125361.0         305203.5  367744.0  367003.300448    367744.0
# 927    114100.0         305203.5  327232.0  331086.371150    327232.0
# 19156  491885.0         305203.5  332032.0  330988.408923    332032.0
#
#        tweedie_preds
# 39518  382586.600292
# 36470  354963.621868
# 14646  388688.209291
# 6714   349663.390637
# 44146  334972.420109
# ...              ...
# 14332  335389.463138
# 54643  349343.400717
# 46604  336523.027522
# 927    329723.547148
# 19156  348790.228590
#
# [27650 rows x 6 columns]

# %%
tweedie_norm = sqrt(mean_squared_error(preds_df['actual'], preds_df['tweedie_preds']))

tweedie_norm
# Out:
# 224743.78428993176

# %%
X_polynomial = poly_subset(X_train_scaled, y_train)

# %%
poly_model(X_polynomial, y_train, LinearRegression())
# Out:
#          actual  baseline_median  lm_preds    lasso_preds  poly_preds  \
# 39518  367584.0         305203.5  382336.0  382371.938598    379792.0
# 36470  414224.0         305203.5  334848.0  335263.900366    322984.0
# 14646  565097.0         305203.5  529600.0  530739.880620    541168.0
# 6714   238731.0         305203.5  275200.0  274215.856123    286280.0
# 44146  256532.0         305203.5  339264.0  338117.607110    360784.0
# ...         ...              ...       ...            ...         ...
# 14332  176100.0         305203.5  314048.0  313181.452828    314384.0
# 54643   77121.0         305203.5  374016.0  372960.605076    394256.0
# 46604  125361.0         305203.5  367744.0  367003.300448    375952.0
# 927    114100.0         305203.5  327232.0  331086.371150    309968.0
# 19156  491885.0         305203.5  332032.0  330988.408923    351240.0
#
#        tweedie_preds
# 39518  382586.600292
# 36470  354963.621868
# 14646  388688.209291
# 6714   349663.390637
# 44146  334972.420109
# ...              ...
# 14332  335389.463138
# 54643  349343.400717
# 46604  336523.027522
# 927    329723.547148
# 19156  348790.228590
#
# [27650 rows x 6 columns]

# %%
poly_rmse = sqrt(mean_squared_error(preds_df['actual'], preds_df['poly_preds']))

poly_rmse
# Out:
# 199157.55520772957

# %% [markdown]
# Polynomial with a degree of 2 and Linear Regression is best so far

# %%
results = pd.DataFrame({'model':['linear', 'lasso', 'tweedie_norm', 'linear_poly'],
              'rmse':[lm_rmse, lasso_rmse, tweedie_norm, poly_rmse]})

results
# Out:
#           model           rmse
# 0        linear  201151.254824
# 1         lasso  201145.616295
# 2  tweedie_norm  224743.784290
# 3   linear_poly  199157.555208

# %%
get_rmses(preds_df)
# Out:
# Linear Regression RMSE is: 201151.25482385387
# Lasso-Lars Regression RMSE is: 201145.61629488488
# GLM Regression RMSE is: 224743.78428993176
# Polynomial Regression RMSE is: 199157.55520772957

# %% [markdown]
# # Again, but with feature engineering

# %% [markdown]
# ## selectkbest

# %%
cols = ['sqft', 'year_built']

X_train_scaled, X_validate_scaled, X_test_scaled = prepare.scale_data(X_train, X_validate, X_test, MinMaxScaler(), cols)

# %%
X_train_scaled = f_selector(4, X_train_scaled, y_train)

# %%
X_train_scaled = pd.get_dummies(X_train_scaled, columns=['bedrooms', 'bathrooms'])

# %%
X_train_scaled
# Out:
#            sqft  year_built  bedrooms_2.0  bedrooms_3.0  bedrooms_4.0  \
# 39518  0.410496    0.603604             0             0             1
# 36470  0.378717    0.819820             0             0             1
# 14646  0.664431    0.765766             0             0             1
# 6714   0.281633    0.378378             0             0             1
# 44146  0.346064    0.324324             0             1             0
# ...         ...         ...           ...           ...           ...
# 14332  0.300000    0.468468             0             1             0
# 54643  0.521283    0.450450             0             0             0
# 46604  0.394169    0.423423             0             1             0
# 927    0.362391    0.405405             0             1             0
# 19156  0.446939    0.531532             0             0             0
#
#        bedrooms_5.0  bathrooms_1.0  bathrooms_1.5  bathrooms_2.0  \
# 39518             0              0              0              0
# 36470             0              0              0              1
# 14646             0              0              0              0
# 6714              0              0              0              1
# 44146             0              0              0              1
# ...             ...            ...            ...            ...
# 14332             0              0              0              1
# 54643             1              0              0              1
# 46604             0              0              0              1
# 927               0              1              0              0
# 19156             1              0              0              1
#
#        bathrooms_2.5  bathrooms_3.0  bathrooms_3.5  bathrooms_4.0  \
# 39518              0              1              0              0
# 36470              0              0              0              0
# 14646              0              1              0              0
# 6714               0              0              0              0
# 44146              0              0              0              0
# ...              ...            ...            ...            ...
# 14332              0              0              0              0
# 54643              0              0              0              0
# 46604              0              0              0              0
# 927                0              0              0              0
# 19156              0              0              0              0
#
#        bathrooms_4.5
# 39518              0
# 36470              0
# 14646              0
# 6714               0
# 44146              0
# ...              ...
# 14332              0
# 54643              0
# 46604              0
# 927                0
# 19156              0
#
# [27650 rows x 14 columns]

# %%
preds_df = create_preds_df(y_train)

# %%
preds_df = lin_regression(X_train_scaled, y_train)

# %%
preds_df
# Out:
#          actual  baseline_median  lm_preds
# 39518  367584.0         305203.5  382336.0
# 36470  414224.0         305203.5  334848.0
# 14646  565097.0         305203.5  529600.0
# 6714   238731.0         305203.5  275200.0
# 44146  256532.0         305203.5  339264.0
# ...         ...              ...       ...
# 14332  176100.0         305203.5  314048.0
# 54643   77121.0         305203.5  374016.0
# 46604  125361.0         305203.5  367744.0
# 927    114100.0         305203.5  327232.0
# 19156  491885.0         305203.5  332032.0
#
# [27650 rows x 3 columns]

# %%
preds_df = lasso_lars(X_train_scaled, y_train)

# %%
preds_df = glm_model(X_train_scaled, y_train, 1)

# %%
poly_subset(X_train_scaled, y_train, 3)
# Out:
# array([[1.        , 0.41049563, 0.6036036 , ..., 0.        , 0.        ,
#         0.        ],
#        [1.        , 0.3787172 , 0.81981982, ..., 0.        , 0.        ,
#         0.        ],
#        [1.        , 0.66443149, 0.76576577, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [1.        , 0.3941691 , 0.42342342, ..., 0.        , 0.        ,
#         0.        ],
#        [1.        , 0.36239067, 0.40540541, ..., 0.        , 0.        ,
#         0.        ],
#        [1.        , 0.44693878, 0.53153153, ..., 0.        , 0.        ,
#         0.        ]])

# %%
poly_model(X_train_scaled, y_train, LinearRegression())
# Out:
#          actual  baseline_median  lm_preds    lasso_preds  tweedie_preds  \
# 39518  367584.0         305203.5  382336.0  382371.938598  373393.240084
# 36470  414224.0         305203.5  334848.0  335263.900366  325013.299560
# 14646  565097.0         305203.5  529600.0  530739.880620  532005.673971
# 6714   238731.0         305203.5  275200.0  274215.856123  282799.455621
# 44146  256532.0         305203.5  339264.0  338117.607110  330480.117703
# ...         ...              ...       ...            ...            ...
# 14332  176100.0         305203.5  314048.0  313181.452828  310459.997083
# 54643   77121.0         305203.5  374016.0  372960.605076  361461.451270
# 46604  125361.0         305203.5  367744.0  367003.300448  353644.608524
# 927    114100.0         305203.5  327232.0  331086.371150  296333.990329
# 19156  491885.0         305203.5  332032.0  330988.408923  326291.021732
#
#        poly_preds
# 39518    382336.0
# 36470    334848.0
# 14646    529600.0
# 6714     275200.0
# 44146    339264.0
# ...           ...
# 14332    314048.0
# 54643    374016.0
# 46604    367744.0
# 927      327232.0
# 19156    332032.0
#
# [27650 rows x 6 columns]

# %%
sqrt(mean_squared_error(y_train, preds_df['poly_preds']))
# Out:
# 201151.25482385387

# %%
get_rmses(preds_df)
# Out:
# Linear Regression RMSE is: 201151.25482385387
# Lasso-Lars Regression RMSE is: 201145.61629488488
# GLM Regression RMSE is: 201574.06010070135
# Polynomial Regression RMSE is: 201151.25482385387

# %% [markdown]
# ## rfe

# %%
rfe(3, X_train_scaled, y_train)
# Out:
#    ranking        feature
# 7        1  bathrooms_1.0
# 8        1  bathrooms_1.5
# 9        1  bathrooms_2.0

# %%
preds_df = create_preds_df(y_train)

# %%
preds_df = lin_regression(X_train_scaled, y_train)

# %%
preds_df = lasso_lars(X_train_scaled, y_train)

# %%
preds_df = glm_model(X_train_scaled, y_train, 1)

# %%
preds_df
# Out:
#          actual  baseline_median       lm_preds    lasso_preds  tweedie_preds
# 39518  367584.0         305203.5  411279.992724  411217.187658  351356.679349
# 36470  414224.0         305203.5  317456.467542  317661.299439  351356.679349
# 14646  565097.0         305203.5  517087.201223  517134.905453  351356.679349
# 6714   238731.0         305203.5  265101.887586  265172.263586  351356.679349
# 44146  256532.0         305203.5  371335.813727  371239.208445  351356.679349
# ...         ...              ...            ...            ...            ...
# 14332  176100.0         305203.5  305047.062896  305052.515004  351356.679349
# 54643   77121.0         305203.5  398487.895525  398631.707498  351356.679349
# 46604  125361.0         305203.5  359456.009697  359448.783816  351356.679349
# 927    114100.0         305203.5  326357.659000  326454.630197  351356.679349
# 19156  491885.0         305203.5  355184.629498  355352.214592  351356.679349
#
# [27650 rows x 5 columns]

# %%
poly_model(X_train_scaled, y_train, LinearRegression())
# Out:
#          actual  baseline_median       lm_preds    lasso_preds  tweedie_preds  \
# 39518  367584.0         305203.5  411279.992724  411217.187658  351356.679349
# 36470  414224.0         305203.5  317456.467542  317661.299439  351356.679349
# 14646  565097.0         305203.5  517087.201223  517134.905453  351356.679349
# 6714   238731.0         305203.5  265101.887586  265172.263586  351356.679349
# 44146  256532.0         305203.5  371335.813727  371239.208445  351356.679349
# ...         ...              ...            ...            ...            ...
# 14332  176100.0         305203.5  305047.062896  305052.515004  351356.679349
# 54643   77121.0         305203.5  398487.895525  398631.707498  351356.679349
# 46604  125361.0         305203.5  359456.009697  359448.783816  351356.679349
# 927    114100.0         305203.5  326357.659000  326454.630197  351356.679349
# 19156  491885.0         305203.5  355184.629498  355352.214592  351356.679349
#
#           poly_preds
# 39518  411279.992724
# 36470  317456.467542
# 14646  517087.201223
# 6714   265101.887586
# 44146  371335.813727
# ...              ...
# 14332  305047.062896
# 54643  398487.895525
# 46604  359456.009697
# 927    326357.659000
# 19156  355184.629498
#
# [27650 rows x 6 columns]

# %%
get_rmses(preds_df)
# Out:
# Linear Regression RMSE is: 200631.59415393448
# Lasso-Lars Regression RMSE is: 200631.61237402717
# GLM Regression RMSE is: 231806.95778944652
# Polynomial Regression RMSE is: 200631.59415393448

# %% [markdown]
# # Top 3
#
# - polynomial, 2deg, LinReg is #1
# - LinReg, no rfe/selectkbest, is #2
# - LassoLars no rfe/selectkbest, alpha .1 is #3

# %%
X_validate_scaled = pd.get_dummies(X_validate_scaled, columns=['bedrooms', 'bathrooms', 'fips'])

# %%
X_validate_scaled
# Out:
#            sqft  year_built  bedrooms_2.0  bedrooms_3.0  bedrooms_4.0  \
# 5483   0.369096    0.477477             0             0             1
# 4272   0.541108    0.576577             0             0             0
# 1071   0.713120    0.612613             0             0             0
# 19292  0.329155    0.504505             0             0             1
# 8910   0.137609    0.486486             1             0             0
# ...         ...         ...           ...           ...           ...
# 13874  0.638776    0.864865             0             0             1
# 9654   0.463557    0.378378             0             0             1
# 7807   0.365015    0.513514             0             0             1
# 27834  0.206997    0.144144             0             1             0
# 16359  0.202915    0.063063             0             1             0
#
#        bedrooms_5.0  bathrooms_1.0  bathrooms_1.5  bathrooms_2.0  \
# 5483              0              0              0              1
# 4272              1              0              0              0
# 1071              1              0              0              0
# 19292             0              0              0              1
# 8910              0              1              0              0
# ...             ...            ...            ...            ...
# 13874             0              0              0              0
# 9654              0              0              0              1
# 7807              0              0              0              1
# 27834             0              1              0              0
# 16359             0              1              0              0
#
#        bathrooms_2.5  bathrooms_3.0  bathrooms_3.5  bathrooms_4.0  \
# 5483               0              0              0              0
# 4272               0              1              0              0
# 1071               0              1              0              0
# 19292              0              0              0              0
# 8910               0              0              0              0
# ...              ...            ...            ...            ...
# 13874              0              0              0              1
# 9654               0              0              0              0
# 7807               0              0              0              0
# 27834              0              0              0              0
# 16359              0              0              0              0
#
#        bathrooms_4.5  fips_6037.0  fips_6059.0
# 5483               0            1            0
# 4272               0            1            0
# 1071               0            1            0
# 19292              0            0            1
# 8910               0            0            1
# ...              ...          ...          ...
# 13874              0            1            0
# 9654               0            1            0
# 7807               0            0            1
# 27834              0            1            0
# 16359              0            1            0
#
# [9217 rows x 16 columns]

# %%
preds_df = create_preds_df(y_validate)

# %%
preds_df = lin_regression(X_validate_scaled, y_validate)

# %%
preds_df = lasso_lars(X_validate_scaled, y_validate)

# %%
preds_df = glm_model(X_validate_scaled, y_validate, 1)

# %%
X_polynomial = poly_subset(X_validate_scaled, y_validate, 3)

# %%
poly_model(X_validate_scaled, y_validate, LinearRegression())
# Out:
#           actual  baseline_median       lm_preds    lasso_preds  \
# 5483    350016.0         300000.0  315847.848183  315879.817479
# 4272    304817.0         300000.0  412819.810416  412855.956434
# 1071    747874.0         300000.0  510700.988441  510723.396052
# 19292    97324.0         300000.0  330122.432971  330138.574889
# 8910    162994.0         300000.0  257687.369571  257663.912346
# ...          ...              ...            ...            ...
# 13874  1040710.0         300000.0  538879.655238  538851.003568
# 9654    514602.0         300000.0  369295.493206  369323.189602
# 7807    203539.0         300000.0  350531.997103  350545.233735
# 27834   272110.0         300000.0  223912.139646  223945.643340
# 16359   673096.0         300000.0  221384.360351  221420.397707
#
#        tweedie_preds     poly_preds
# 5483   345486.436585  315847.848183
# 4272   345486.436585  412819.810416
# 1071   345486.436585  510700.988441
# 19292  345486.436585  330122.432971
# 8910   345486.436585  257687.369571
# ...              ...            ...
# 13874  345486.436585  538879.655238
# 9654   345486.436585  369295.493206
# 7807   345486.436585  350531.997103
# 27834  345486.436585  223912.139646
# 16359  345486.436585  221384.360351
#
# [9217 rows x 6 columns]

# %%
get_rmses(preds_df)
# Out:
# Linear Regression RMSE is: 197846.735294878
# Lasso-Lars Regression RMSE is: 197846.73687149206
# GLM Regression RMSE is: 227428.42957956833
# Polynomial Regression RMSE is: 197846.735294878

# %% [markdown]
# - Polynomial with a Degree of 2, using LinearRegression has an rmse of 197846.7
#
# - LinearRegression rmse is 197846.7 as well
#
# - LassoLars with no rfe or selectkbest using an alpha of .1 has an rmse of 197846.7 (the same, rounded, but very slightly different
